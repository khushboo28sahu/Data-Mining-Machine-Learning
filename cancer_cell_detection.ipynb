# %% [markdown]
# <a href="https://colab.research.google.com/github/khushboo28sahu/Data-Mining-Machine-Learning/blob/main/cancer_cell_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
col_names=['id','diagno','rad_mean','tex_mean','peri_mean','area_mean','smooth_mean','compact_mean','concavity_mean','con_point_mean','sym_mean','fra_dim_mean','rad_se','texture_se','peri_se','area_se','smooth_se','compact_se','conca_se','conc_points_se','symm_se','frac_dim_se','rad_worst','text_worst','per_worst','area_worst','smoot_wors','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']
bs=pd.read_csv("wisc_bc_data.csv",header=None,names=col_names)

# %%
bs
# Out:
#            id diagno  rad_mean  tex_mean  peri_mean  area_mean  smooth_mean  \
# 0      842302      M    17.990     10.38     122.80     1001.0      0.11840
# 1      842517      M    20.570     17.77     132.90     1326.0      0.08474
# 2    84300903      M    19.690     21.25     130.00     1203.0      0.10960
# 3    84348301      M    11.420     20.38      77.58      386.1      0.14250
# 4    84358402      M    20.290     14.34     135.10     1297.0      0.10030
# 5      843786      M    12.450     15.70      82.57      477.1      0.12780
# 6      844359      M    18.250     19.98     119.60     1040.0      0.09463
# 7    84458202      M    13.710     20.83      90.20      577.9      0.11890
# 8      844981      M    13.000     21.82      87.50      519.8      0.12730
# 9    84501001      M    12.460     24.04      83.97      475.9      0.11860
# 10     845636      M    16.020     23.24     102.70      797.8      0.08206
# ...

# %%
a = bs['diagno']

# %%
a.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagno, dtype: object

# %%
#bs['diagno']

# %%
X = bs.drop(['diagno'], axis=1)

# %%
X=bs.iloc[:, :-1].values
y=a #bs['diagno']

# %%
y.head(10)
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# 5    M
# 6    M
# 7    M
# 8    M
# 9    M
# Name: diagno, dtype: object

# %%
X.head()
# Out:
#          id  rad_mean  tex_mean  peri_mean  area_mean  smooth_mean  \
# 0    842302     17.99     10.38     122.80     1001.0      0.11840
# 1    842517     20.57     17.77     132.90     1326.0      0.08474
# 2  84300903     19.69     21.25     130.00     1203.0      0.10960
# 3  84348301     11.42     20.38      77.58      386.1      0.14250
# 4  84358402     20.29     14.34     135.10     1297.0      0.10030
#
#    compact_mean  concavity_mean  con_point_mean  sym_mean  ...  rad_worst  \
# 0       0.27760          0.3001         0.14710    0.2419  ...      25.38
# 1       0.07864          0.0869         0.07017    0.1812  ...      24.99
# 2       0.15990          0.1974         0.12790    0.2069  ...      23.57
# 3       0.28390          0.2414         0.10520    0.2597  ...      14.91
# 4       0.13280          0.1980         0.10430    0.1809  ...      22.54
#
#    text_worst  per_worst  area_worst  smoot_wors  compactness_worst  \
# ...

# %%
X.head(10)
#X.shape
# Out:
#          id  rad_mean  tex_mean  peri_mean  area_mean  smooth_mean  \
# 0    842302     17.99     10.38     122.80     1001.0      0.11840
# 1    842517     20.57     17.77     132.90     1326.0      0.08474
# 2  84300903     19.69     21.25     130.00     1203.0      0.10960
# 3  84348301     11.42     20.38      77.58      386.1      0.14250
# 4  84358402     20.29     14.34     135.10     1297.0      0.10030
# 5    843786     12.45     15.70      82.57      477.1      0.12780
# 6    844359     18.25     19.98     119.60     1040.0      0.09463
# 7  84458202     13.71     20.83      90.20      577.9      0.11890
# 8    844981     13.00     21.82      87.50      519.8      0.12730
# 9  84501001     12.46     24.04      83.97      475.9      0.11860
#
#    compact_mean  concavity_mean  con_point_mean  sym_mean  ...  rad_worst  \
# 0       0.27760         0.30010         0.14710    0.2419  ...      25.38
# 1       0.07864         0.08690         0.07017    0.1812  ...      24.99
# ...

# %%
y.shape
# Out:
# (569,)

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
# 5      M
# 6      M
# 7      M
# 8      M
# 9      M
# 10     M
# 11     M
# 12     M
# 13     M
# 14     M
# 15     M
# 16     M
# 17     M
# 18     M
# 19     B
# 20     B
# 21     B
# 22     M
# 23     M
# 24     M
# 25     M
# 26     M
# 27     M
# 28     M
# 29     M
#       ..
# 539    B
# 540    B
# 541    B
# 542    B
# 543    B
# 544    B
# 545    B
# 546    B
# 547    B
# 548    B
# 549    B
# 550    B
# 551    B
# 552    B
# 553    B
# 554    B
# 555    B
# 556    B
# 557    B
# 558    B
# 559    B
# 560    B
# 561    B
# 562    M
# 563    M
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagno, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train
# Out:
#             id  rad_mean  tex_mean  peri_mean  area_mean  smooth_mean  \
# 227   88147102    15.000     15.51      97.45      684.5      0.08371
# 286    8912909    11.940     20.76      77.87      441.0      0.08605
# 381     901836    11.040     14.93      70.67      372.7      0.07987
# 321     894618    20.160     19.66     131.10     1274.0      0.08020
# 418     906024    12.700     12.17      80.88      495.0      0.08785
# 495     914333    14.870     20.21      96.12      680.9      0.09587
# 500     914862    15.040     16.74      98.73      689.4      0.09883
# 174     871642    10.660     15.15      67.49      349.6      0.08792
# 454     911202    12.620     17.15      80.62      492.9      0.08583
# 39      855138    13.480     20.82      88.40      559.2      0.10160
# 302   89263202    20.090     23.86     134.70     1247.0      0.10800
# 496     914366    12.650     18.17      82.69      485.6      0.10760
# ...

# %%
y_train
# Out:
# 227    B
# 286    B
# 381    B
# 321    M
# 418    B
# 495    B
# 500    B
# 174    B
# 454    B
# 39     M
# 302    M
# 496    B
# 455    B
# 206    B
# 223    M
# 372    M
# 18     M
# 109    B
# 457    B
# 108    M
# 66     B
# 60     B
# 551    B
# 453    B
# 152    B
# 473    B
# 304    B
# 141    M
# 437    B
# 269    B
#       ..
# 479    M
# 333    B
# 378    B
# 506    B
# 55     B
# 546    B
# 171    M
# 362    B
# 190    M
# 93     B
# 211    B
# 204    B
# 100    M
# 310    B
# 391    B
# 267    B
# 150    B
# 432    M
# 494    B
# 219    M
# 80     B
# 548    B
# 243    B
# 470    B
# 307    B
# 147    B
# 229    M
# 439    B
# 471    B
# 8      M
# Name: diagno, Length: 455, dtype: object

# %%
X_train.shape
# Out:
# (455, 31)

# %%
y_train.shape
# Out:
# (455,)

# %%
X_test.shape
# Out:
# (114, 31)

# %%
y_test.shape
# Out:
# (114,)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
scale.fit(X_train)
X_train=scale.transform(X_train)
X_test=scale.transform(X_test)
#y_train=y_train.reshape(-1,1)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier5=KNeighborsClassifier(n_neighbors=5)
classifier5.fit(X_train,y_train)
classifier7=KNeighborsClassifier(n_neighbors=7)
classifier7.fit(X_train,y_train)
classifier9=KNeighborsClassifier(n_neighbors=9)
classifier9.fit(X_train,y_train)
classifier13=KNeighborsClassifier(n_neighbors=13)
classifier13.fit(X_train,y_train)
classifier15=KNeighborsClassifier(n_neighbors=15)
classifier15.fit(X_train,y_train)
classifier19=KNeighborsClassifier(n_neighbors=19)
classifier19.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#                      weights='uniform')

# %%
y_pred5=classifier5.predict(X_test)
y_pred7=classifier7.predict(X_test)
y_pred9=classifier9.predict(X_test)
y_pred13=classifier13.predict(X_test)
y_pred15=classifier15.predict(X_test)
y_pred19=classifier19.predict(X_test)

# %%
y_pred7
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B'], dtype=object)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,y_pred7))
# Out:
# [[70  0]
#  [ 3 41]]

# %%
print(classification_report(y_test,y_pred7))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      1.00      0.98        70
#            M       1.00      0.93      0.96        44
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
error=[]
range1=[5,11,15,17,21]
for i in range1:
    classes=KNeighborsClassifier(n_neighbors=i)
    classes.fit(X_train,y_train)
    pred=classifier.predict(X_test)
    error.append(np.mean(pred!=y_pred))

# %%
plt.figure(figsize=(12,6))

# %%
plt.plot(range1,error,color='bLack',linestyle='dashed',marker='o',markerfacecolor='red',markersize=15)
